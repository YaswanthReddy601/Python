# %%
import zipfile

# %%
unzip = zipfile.ZipFile("C:\\Users\\yaswa\\Desktop\\My_python\\session14\\unzip_me_for_instructions.zip","r")

# %%
unzip.extractall("unzip_me_for_instructions")

# %%
import os

# %%
for folder,sub_folder,files in os.walk("C:\\Users\\yaswa\\Desktop\\My_python\\session14\\unzip_me_for_instructions"):
    print("Current directory: "+folder)
    print("\n")
    print("sub_folders :")
    for sub in sub_folder:
        print("sub_folders are : "+sub)
       
    for f in files:
        print("files : "+f)
        
    print("\n")
# Out:
# Current directory: C:\Users\yaswa\Desktop\My_python\session14\unzip_me_for_instructions
#
#
# sub_folders :
# sub_folders are : extracted_content
#
#
# Current directory: C:\Users\yaswa\Desktop\My_python\session14\unzip_me_for_instructions\extracted_content
#
#
# sub_folders :
# sub_folders are : Five
# sub_folders are : Four
# sub_folders are : One
# sub_folders are : Three
# sub_folders are : Two
# files : Instructions.txt
#
#
# Current directory: C:\Users\yaswa\Desktop\My_python\session14\unzip_me_for_instructions\extracted_content\Five
#
#
# sub_folders :
# files : AEITMYIRQLP.txt
# files : APJKSRITGGX.txt
# files : AQKATDFGXTS.txt
# files : ARLKFCWIAJE.txt
# files : AXJGVPVEFAS.txt
# files : BNUQEHCFRTG.txt
# files : BSKJDRNEZQM.txt
# files : BTYWAHLHKBM.txt
# files : BUGKBZWRRVI.txt
# files : BVBURZZCAPR.txt
# files : CAHBEVSVDDN.txt
# files : COMGMZBJAYE.txt
# files : CRFSDGYFSHA.txt
# files : CSCLFZCDYYC.txt
# files : CXBVCTRBBIE.txt
# files : DDLASODUVPX.txt
# ...
